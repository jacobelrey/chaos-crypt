# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# %%
x,y,z = np.loadtxt("SystemB/expectedOutput.csv",delimiter=',',unpack=True)
x1,y1,z1=np.loadtxt("SystemB/output.csv",delimiter=',',unpack=True)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_45048/2398141501.py in <module>
# ----> 1 x,y,z = np.loadtxt("output.csv",delimiter=',',unpack=True)
#       2 x1,y1,z1=np.loadtxt("output1.csv",delimiter=',',unpack=True)
#
# ~/.local/lib/python3.9/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    1065             fname = os_fspath(fname)
#    1066         if _is_string_like(fname):
# -> 1067             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1068             fencoding = getattr(fh, 'encoding', 'latin1')
#    1069             fh = iter(fh)
#
# ~/.local/lib/python3.9/site-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     191
#     192     ds = DataSource(destpath)
# ...

# %%
fig = plt.figure()
ax = plt.axes(projection="3d")
ax.plot3D(x[60198:],y[60198:],z[60198:])
ax.plot3D(x1[60198:],y1[60198:],z1[60198:])
plt.show()

# %%
plt.plot(x[60198:],x1[60198:])
