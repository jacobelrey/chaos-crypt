# %% [markdown]
# # Performance Analysis of Chaotic Encryption System

# %% [markdown]
# #### This file tests the performance of a chaotic encryption system for sensitivity
#
# ##### Compares the apparent difference between the encrypted data and the original and the values of each parameter.  The optimum trend is for the values to trend towards 0.5

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.genfromtxt('../src/data.csv', delimiter = ',')

# %%
fig, axs = plt.subplots(2, 2)
axs[0, 0].scatter(data[:,1], data[:,0])
axs[0, 0].set_title('variance vs. σ')
axs[0, 1].scatter(data[:,2], data[:,0])
axs[0, 1].set_title('variance vs. ρ')
axs[1, 0].scatter(data[:,3], data[:,0])
axs[1, 0].set_title('variance vs. β')
axs[1, 1].scatter(data[:,4], data[:,0])
axs[1, 1].set_title('variance vs. γ')

for ax in axs.flat:
    ax.set(xlabel='parameter', ylabel='variance')

# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()

# %%
plt.scatter(data[:,1][:100], data[:,0][:100], label = '2.2kb file')
plt.scatter(data[:,1][100:200], data[:,0][100:200], label = '46mb file')
plt.scatter(data[:,1][200:300], data[:,0][200:300], label = '8.4mb file')
plt.scatter(data[:,1][300:400], data[:,0][300:400], label = '1.4mb file')
plt.scatter(data[:,1][400:500], data[:,0][400:500], label = '15.0mb file')
plt.scatter(data[:,1][500:600], data[:,0][500:600], label = '8.4mb file')
plt.scatter(data[:,1][600:700], data[:,0][600:700], label = '5.4mb file')



plt.legend()
plt.title('similarity between bits between original and encrypted data vs. σ')
plt.xlabel('σ');
plt.ylabel('probability')
# Out:
# Text(0, 0.5, 'probability')

# %%
plt.scatter(data[:,2][:100], data[:,0][:100], label = '2.2kb file')
plt.scatter(data[:,2][100:200], data[:,0][100:200], label = '46mb file')
plt.scatter(data[:,2][200:300], data[:,0][200:300], label = '8.4mb file')
plt.scatter(data[:,2][300:400], data[:,0][300:400], label = '1.4mb file')
plt.scatter(data[:,2][400:500], data[:,0][400:500], label = '15.0mb file')
plt.scatter(data[:,2][500:600], data[:,0][500:600], label = '8.4mb file')
plt.scatter(data[:,2][600:700], data[:,0][600:700], label = '5.4mb file')



plt.legend()
plt.title('similarity between bits between original and encrypted data vs. σ')
plt.xlabel('σ');
plt.ylabel('probability')
# Out:
# Text(0, 0.5, 'probability')

# %%
plt.scatter(data[:,3][:100], data[:,0][:100], label = '2.2kb file')
plt.scatter(data[:,3][100:200], data[:,0][100:200], label = '46mb file')
plt.scatter(data[:,3][200:300], data[:,0][200:300], label = '8.4mb file')
plt.scatter(data[:,3][300:400], data[:,0][300:400], label = '1.4mb file')
plt.scatter(data[:,3][400:500], data[:,0][400:500], label = '15.0mb file')
plt.scatter(data[:,3][500:600], data[:,0][500:600], label = '8.4mb file')
plt.scatter(data[:,3][600:700], data[:,0][600:700], label = '5.4mb file')



plt.legend()
plt.title('similarity between bits between original and encrypted data vs. σ')
plt.xlabel('σ');
plt.ylabel('probability')
# Out:
# Text(0, 0.5, 'probability')

# %%
plt.scatter(data[:,4][:100], data[:,0][:100], label = '2.2kb file')
plt.scatter(data[:,4][100:200], data[:,0][100:200], label = '46mb file')
plt.scatter(data[:,4][200:300], data[:,0][200:300], label = '8.4mb file')
plt.scatter(data[:,4][300:400], data[:,0][300:400], label = '1.4mb file')
plt.scatter(data[:,4][400:500], data[:,0][400:500], label = '15.0mb file')
plt.scatter(data[:,4][500:600], data[:,0][500:600], label = '8.4mb file')
plt.scatter(data[:,4][600:700], data[:,0][600:700], label = '5.4mb file')



plt.legend()
plt.title('similarity between bits between original and encrypted data vs. σ')
plt.xlabel('σ');
plt.ylabel('probability')
# Out:
# Text(0, 0.5, 'probability')
