# %% [markdown]
# # Performance Analysis of Chaotic Encryption System

# %% [markdown]
# #### This file tests the performance of a chaotic encryption system for sensitivity
#
# ##### Compares the apparent difference between the encrypted data and the original and the values of each parameter.  The optimum trend is for the values to trend towards 0.5

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.genfromtxt('../src/data.csv', delimiter = ',')

# %%
fig, axs = plt.subplots(2, 2)
axs[0, 0].scatter(data[:,1], data[:,0])
axs[0, 0].set_title('variance vs. σ')
axs[0, 1].scatter(data[:,2], data[:,0])
axs[0, 1].set_title('variance vs. ρ')
axs[1, 0].scatter(data[:,3], data[:,0])
axs[1, 0].set_title('variance vs. β')
axs[1, 1].scatter(data[:,4], data[:,0])
axs[1, 1].set_title('variance vs. γ')

for ax in axs.flat:
    ax.set(xlabel='parameter', ylabel='variance')

# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()

# %%
plt.scatter(data[:,1][:100], data[:,0][:100], label = '2.2kb file')
plt.scatter(data[:,1][100:200], data[:,0][100:200], label = '46mb file')
plt.scatter(data[:,1][200:300], data[:,0][200:300], label = '8.4mb file')
plt.scatter(data[:,1][300:400], data[:,0][300:400], label = '1.4mb file')
plt.scatter(data[:,1][300:400], data[:,0][300:400], label = '15.0mb file')
plt.scatter(data[:,1][300:400], data[:,0][300:400], label = '1.4mb file')
plt.scatter(data[:,1][300:400], data[:,0][300:400], label = '1.4mb file')



plt.legend()
plt.title('similarity between bits between original and encrypted data vs. σ')
plt.xlabel('σ');
plt.ylabel('probability')
# Out:
# Text(0, 0.5, 'probability')

# %%
# Out:
# array([2.41623676e+38, 1.81890560e+38, 8.81163302e+37, 3.79182918e+37,
#        2.08486803e+38, 7.30337118e+37, 3.27005360e+38, 5.41574563e+37,
#        1.81309388e+38, 1.29868684e+38, 7.31771896e+37, 8.39235099e+37,
#        6.17210761e+37, 2.72308264e+38, 1.50371523e+38, 9.91618262e+37,
#        3.38346938e+38, 1.93214635e+38, 8.99065774e+37, 2.66775467e+38,
#        2.47832751e+38, 5.24011486e+36, 6.98234500e+36, 2.79095144e+38,
#        2.52437426e+38, 1.79521291e+38, 2.98884772e+38, 5.10326773e+37,
#        1.18273150e+38, 3.28164520e+38, 1.88316291e+38, 1.90608386e+38,
#        6.11900015e+37, 6.99475809e+37, 1.24190188e+38, 6.40546079e+37,
#        1.68935202e+38, 2.83317414e+38, 2.92269462e+38, 6.36837390e+37,
#        1.74655318e+38, 1.12089347e+38, 3.39050109e+38, 1.66237621e+38,
#        1.10351297e+38, 2.16389925e+38, 1.17863181e+38, 3.07336493e+38,
#        1.21611665e+38, 1.01898055e+38, 3.08601750e+38, 2.16407591e+38,
#        2.08809820e+38, 2.75382895e+38, 9.54129042e+36, 2.89331413e+38,
#        1.18955115e+38, 1.78188290e+38, 6.74884604e+37, 2.17200511e+38,
#        3.14715741e+38, 1.03364311e+38, 2.21841167e+38, 1.33674212e+38,
